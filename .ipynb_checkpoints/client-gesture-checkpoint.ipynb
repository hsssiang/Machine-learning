# %%
from tkinter import *
import tkinter as tk
from PIL  import Image, ImageTk
import random
import socket
import time

ip = '192.168.56.1'
port = 5000
s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
s.bind((ip,port))
s.listen(5)

a=1  #记录图片变量的编号，同时也与图片名称对应
root = tk.Tk()
root.title("旗語")
root.geometry("800x600")
canvas = tk.Canvas(root,width=800, height=800,bg='white')
canvas.pack()
list2=[0,0]

def motion():
    global a
    gesture_dict = {
        'A': var1, 'B': var2, 'C': var3, 'D': var4, 'E': var5, 'F': var6, 'G': var7, 'H': var8, 'I': var9, 'J': var10,
        'K': var11, 'L': var12, 'M': var13, 'N': var14, 'O': var15, 'P': var16, 'Q': var17, 'R': var18, 'S': var19, 'T': var20,
        'U': var21, 'V': var22, 'W': var23, 'X': var24, 'Y': var25, 'Z': var26,
        'switch': var27, 'ready': var28, 'error': var29
    }

    a = list2[-1]

    if a != '0' and a in gesture_dict:
        selected_image = gesture_dict[a]
        canvas.delete("a")
        canvas.create_image(380, 200, image=selected_image, tags="a")

def check_socket_data():
    try:
        data = c.recv(1024)
        list2.append(data.decode())
        print(data)
        motion()
    except:
        pass
    root.after(5000, check_socket_data)


load = Image.open("1.jpg")
var1= ImageTk.PhotoImage(load)  
load = Image.open("2.jpg")
var2= ImageTk.PhotoImage(load)  
load = Image.open("3.jpg")
var3= ImageTk.PhotoImage(load)  
load = Image.open("4.jpg")
var4= ImageTk.PhotoImage(load)  
load = Image.open("5.jpg")
var5= ImageTk.PhotoImage(load)  
load = Image.open("6.jpg")
var6= ImageTk.PhotoImage(load)  
load = Image.open("7.jpg")
var7= ImageTk.PhotoImage(load)  
load = Image.open("8.jpg")
var8= ImageTk.PhotoImage(load)  
load = Image.open("9.jpg")
var9= ImageTk.PhotoImage(load)
load = Image.open("10.jpg")
var10= ImageTk.PhotoImage(load)
load = Image.open("11.jpg")
var11= ImageTk.PhotoImage(load)
load = Image.open("12.jpg")
var12= ImageTk.PhotoImage(load)
load = Image.open("13.jpg")
var13= ImageTk.PhotoImage(load)
load = Image.open("14.jpg")
var14= ImageTk.PhotoImage(load)
load = Image.open("15.jpg")
var15= ImageTk.PhotoImage(load)
load = Image.open("16.jpg")
var16= ImageTk.PhotoImage(load)
load = Image.open("17.jpg")
var17= ImageTk.PhotoImage(load)
load = Image.open("18.jpg")
var18= ImageTk.PhotoImage(load)
load = Image.open("19.jpg")
var19= ImageTk.PhotoImage(load)
load = Image.open("20.jpg")
var20= ImageTk.PhotoImage(load)
load = Image.open("21.jpg")
var21= ImageTk.PhotoImage(load)
load = Image.open("22.jpg")
var22= ImageTk.PhotoImage(load)
load = Image.open("23.jpg")
var23= ImageTk.PhotoImage(load)
load = Image.open("24.jpg")
var24= ImageTk.PhotoImage(load)
load = Image.open("25.jpg")
var25= ImageTk.PhotoImage(load)
load = Image.open("26.jpg")
var26= ImageTk.PhotoImage(load)
load = Image.open("27.jpg")
var27= ImageTk.PhotoImage(load)
load = Image.open("28.jpg")
var28= ImageTk.PhotoImage(load)
load = Image.open("29.jpg")
var29= ImageTk.PhotoImage(load)

def main():
    global c
    c, addr = s.accept()
    print("Got a connection from %s" % str(addr))
    check_socket_data()
    root.mainloop()
main()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 11
#       9 port = 5000
#      10 s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
# ---> 11 s.bind((ip,port))
#      12 s.listen(5)
#      14 a=1  #记录图片变量的编号，同时也与图片名称对应
#
# OSError: [Errno 49] Can't assign requested address

# %%
from tkinter import *
import tkinter as tk
from PIL  import Image, ImageTk
import random
import socket
import time

ip = '192.168.56.1'
port = 5000
s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
s.bind((ip,port))
s.listen(5)

a=1  #记录图片变量的编号，同时也与图片名称对应
root = tk.Tk()
root.title("旗語")
root.geometry("800x600")
canvas = tk.Canvas(root,width=800, height=800,bg='white')
canvas.pack()
list2=[0,0]

def motion(XD):

    # 使用字典将图像变量与其名称关联
    gesture_dict = {
        'A': var1, 'B': var2, 'C': var3, 'D': var4, 'E': var5, 'F': var6, 'G': var7, 'H': var8, 'I': var9, 'J': var10,
        'K': var11, 'L': var12, 'M': var13, 'N': var14, 'O': var15, 'P': var16, 'Q': var17, 'R': var18, 'S': var19, 'T': var20,
        'U': var21, 'V': var22, 'W': var23, 'X': var24, 'Y': var25, 'Z': var26,
        'switch': var27, 'ready': var28, 'error': var29
    }

    
    print(f'這是{XD}')
    # 检查手势输入是否在字典中，并且不等于 '0'
    if XD in gesture_dict :
        selected_image = gesture_dict[XD]

        canvas.delete("a")
        canvas.create_image(380, 200, image=selected_image, tags="a")
        root.destroy()
        return


load = Image.open("1.jpg")
var1= ImageTk.PhotoImage(load)  
load = Image.open("2.jpg")
var2= ImageTk.PhotoImage(load)  
load = Image.open("3.jpg")
var3= ImageTk.PhotoImage(load)  
load = Image.open("4.jpg")
var4= ImageTk.PhotoImage(load)  
load = Image.open("5.jpg")
var5= ImageTk.PhotoImage(load)  
load = Image.open("6.jpg")
var6= ImageTk.PhotoImage(load)  
load = Image.open("7.jpg")
var7= ImageTk.PhotoImage(load)  
load = Image.open("8.jpg")
var8= ImageTk.PhotoImage(load)  
load = Image.open("9.jpg")
var9= ImageTk.PhotoImage(load)
load = Image.open("10.jpg")
var10= ImageTk.PhotoImage(load)
load = Image.open("11.jpg")
var11= ImageTk.PhotoImage(load)
load = Image.open("12.jpg")
var12= ImageTk.PhotoImage(load)
load = Image.open("13.jpg")
var13= ImageTk.PhotoImage(load)
load = Image.open("14.jpg")
var14= ImageTk.PhotoImage(load)
load = Image.open("15.jpg")
var15= ImageTk.PhotoImage(load)
load = Image.open("16.jpg")
var16= ImageTk.PhotoImage(load)
load = Image.open("17.jpg")
var17= ImageTk.PhotoImage(load)
load = Image.open("18.jpg")
var18= ImageTk.PhotoImage(load)
load = Image.open("19.jpg")
var19= ImageTk.PhotoImage(load)
load = Image.open("20.jpg")
var20= ImageTk.PhotoImage(load)
load = Image.open("21.jpg")
var21= ImageTk.PhotoImage(load)
load = Image.open("22.jpg")
var22= ImageTk.PhotoImage(load)
load = Image.open("23.jpg")
var23= ImageTk.PhotoImage(load)
load = Image.open("24.jpg")
var24= ImageTk.PhotoImage(load)
load = Image.open("25.jpg")
var25= ImageTk.PhotoImage(load)
load = Image.open("26.jpg")
var26= ImageTk.PhotoImage(load)
load = Image.open("27.jpg")
var27= ImageTk.PhotoImage(load)
load = Image.open("28.jpg")
var28= ImageTk.PhotoImage(load)
load = Image.open("29.jpg")
var29= ImageTk.PhotoImage(load)

def main():  
    c,addr=s.accept()
    print("Got a connection from %s" % str(addr))
    while True:
        data = c.recv(1024)
        print('這邊是data',data)
        
        NEWSTR=data.decode()
        print('這邊是NEWSTR',NEWSTR)
        for i in str(NEWSTR):
            if i !=0:
                root.after(5000, motion(i))
        root.mainloop()
   
    
main()
# Out:
# Got a connection from ('192.168.56.1', 51949)
# 這邊是data b'0'
# 這邊是NEWSTR 0
# 這是0
# 這邊是data b'...'
# 這邊是NEWSTR ...
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0
# 這是0

# %%
from tkinter import *
#import tkinter as tk
from tkinter import Tk, Label
from PIL import Image, ImageTk
import random
import socket
import time

ip = '192.168.56.1'
port = 5000
s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
s.bind((ip,port))
s.listen(5)

a=1  #记录图片变量的编号，同时也与图片名称对应
root = Tk()
root.title("旗語")
root.geometry("800x600")
canvas = Canvas(root,width=600, height=600,bg='white')
#canvas.pack()
list2=[0,0]

def motion():
    global a
    gesture_dict = {
        'A': var1, 'B': var2, 'C': var3, 'D': var4, 'E': var5, 'F': var6, 'G': var7, 'H': var8, 'I': var9, 'J': var10,
        'K': var11, 'L': var12, 'M': var13, 'N': var14, 'O': var15, 'P': var16, 'Q': var17, 'R': var18, 'S': var19, 'T': var20,
        'U': var21, 'V': var22, 'W': var23, 'X': var24, 'Y': var25, 'Z': var26,
        'switch': var27, 'ready': var28, 'error': var29
    }

    a = list2[-1]

    if a != '0' and a in gesture_dict:
        selected_image = gesture_dict[a]
        canvas.delete("a")
        canvas.create_image(0, 0, anchor='center', image=selected_image, tags="a")

def check_socket_data():
    try:
        data = c.recv(1024)
        list2.append(data.decode())
        print(data)
        motion()
        
    except:
        pass
    root.after(5000, check_socket_data)

# 创建一个函数来a加载图像并显示
def load_img():
    
    #global var1, var2, var3, var4, var5, var6, var7, var8, var9, var10, var11, var12, var13, var14, var15, var16, var17, var18, var19, var20, var21, var22, var23, var24, var25, var26, var27, var28, var29
    # 设置全局变量 var1 到 var29
    global var1, var2, var3, var4, var5, var6, var7, var8, var9, var10, var11, var12, var13, var14, var15, var16, var17, var18, var19, var20, var21, var22, var23, var24, var25, var26, var27, var28, var29    
    
    load = Image.open("1.jpg")
    var1= ImageTk.PhotoImage(load)
    load = Image.open("2.jpg")
    var2= ImageTk.PhotoImage(load)
    '''
    load = Image.open("3.jpg")
    var3= ImageTk.PhotoImage(load)  
    load = Image.open("4.jpg")
    var4= ImageTk.PhotoImage(load)  
    load = Image.open("5.jpg")
    var5= ImageTk.PhotoImage(load)  
    load = Image.open("6.jpg")
    var6= ImageTk.PhotoImage(load)  
    load = Image.open("7.jpg")
    var7= ImageTk.PhotoImage(load)  
    load = Image.open("8.jpg")
    var8= ImageTk.PhotoImage(load)  
    load = Image.open("9.jpg")
    var9= ImageTk.PhotoImage(load)
    load = Image.open("10.jpg")
    var10= ImageTk.PhotoImage(load)
    load = Image.open("11.jpg")
    var11= ImageTk.PhotoImage(load)
    load = Image.open("12.jpg")
    var12= ImageTk.PhotoImage(load)
    load = Image.open("13.jpg")
    var13= ImageTk.PhotoImage(load)
    load = Image.open("14.jpg")
    var14= ImageTk.PhotoImage(load)
    load = Image.open("15.jpg")
    var15= ImageTk.PhotoImage(load)
    load = Image.open("16.jpg")
    var16= ImageTk.PhotoImage(load)
    load = Image.open("17.jpg")
    var17= ImageTk.PhotoImage(load)
    load = Image.open("18.jpg")
    var18= ImageTk.PhotoImage(load)
    load = Image.open("19.jpg")
    var19= ImageTk.PhotoImage(load)
    load = Image.open("20.jpg")
    var20= ImageTk.PhotoImage(load)
    load = Image.open("21.jpg")
    var21= ImageTk.PhotoImage(load)
    load = Image.open("22.jpg")
    var22= ImageTk.PhotoImage(load)
    load = Image.open("23.jpg")
    var23= ImageTk.PhotoImage(load)
    load = Image.open("24.jpg")
    var24= ImageTk.PhotoImage(load)
    load = Image.open("25.jpg")
    var25= ImageTk.PhotoImage(load)
    load = Image.open("26.jpg")
    var26= ImageTk.PhotoImage(load)
    load = Image.open("27.jpg")
    var27= ImageTk.PhotoImage(load)
    load = Image.open("28.jpg")
    var28= ImageTk.PhotoImage(load)
    load = Image.open("29.jpg")
    var29= ImageTk.PhotoImage(load)
    
    image_vars = [var1, var2, var3, var4, var5, var6, var7, var8, var9, var10, var11, var12, var13, var14, var15, var16, 
                  var17, var18, var19, var20, var21, var22, var23, var24, var25, var26, var27, var28, var29]
    
    # 根据传入的图像索引创建标签并显示图像
    image_index = 0  # 初始显示第一张图像
    label = Label(master=root, image=image_vars[image_index])
    #label.grid(row=0, column=0)'''
    Label(master=root,image=var1).grid(row=0, column=0)
    Label(master=root,image=var2).grid(row=0, column=0)
    #canvas.pack()

def main():
    global c
    c, addr = s.accept()
    print("Got a connection from %s" % str(addr))
    check_socket_data()
    load_img()
    root.mainloop()
main()
# Out:
# Got a connection from ('192.168.56.1', 57449)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de5b35fe18fd> in <module>
#     134     load_img()
#     135     root.mainloop()
# --> 136 main()
#
# <ipython-input-1-de5b35fe18fd> in main()
#     130     c, addr = s.accept()
#     131     print("Got a connection from %s" % str(addr))
# --> 132     motion()
#     133     check_socket_data()
#     134     load_img()
#
# <ipython-input-1-de5b35fe18fd> in motion()
#      24     global a
#      25     gesture_dict = {
# ---> 26         'A': var1, 'B': var2, 'C': var3, 'D': var4, 'E': var5, 'F': var6, 'G': var7, 'H': var8, 'I': var9, 'J': var10,
#      27         'K': var11, 'L': var12, 'M': var13, 'N': var14, 'O': var15, 'P': var16, 'Q': var17, 'R': var18, 'S': var19, 'T': var20,
# ...

# %%
list1=[]
list1.append(text)
list2=[' ',' ']
maxlabel = max(list1,key=list1.count)
list2.append(maxlabel)
            
msg = list2[-1]
                        

            a=1  #记录图片变量的编号，同时也与图片名称对应
            root = Tk()
            root.title("旗語")
            root.geometry("1000x300")
            canvas = Canvas(root,width=1000, height=600,bg='white')
            canvas.pack()

            list1=[]
            list1.append(text)
            list2=[' ',' ']
            #a = statistics.mean(list1)
            #list2.append(a)
            maxlabel = max(list1,key=list1.count)
            list2.append(maxlabel)
            
            #移动鼠标，根据方向绘制新图形
            def pick(event):
                global a,flag
                if text=='A':
                    a+=1
                    if a>=5:
                        a=1
                else:			
                    a+=1
                    if a>=9:
                        a=5
                if list2[-1] != list2[-2]:
                    canvas.delete('a')
                    canvas.create_image(list2[-1],200,image=var29,tags="a")
                    return
                canvas.delete('a')
                exec('canvas.create_image(list2[-1],150,image=var{},tags="a")'.format(a))
                
            load = Image.open("1.jpg")
            var1= ImageTk.PhotoImage(load)  
            load = Image.open("2.jpg")
            var2= ImageTk.PhotoImage(load)  
            load = Image.open("3.jpg")
            var3= ImageTk.PhotoImage(load)  
            load = Image.open("4.jpg")
            var4= ImageTk.PhotoImage(load)  
            load = Image.open("5.jpg")
            var5= ImageTk.PhotoImage(load)  
            load = Image.open("6.jpg")
            var6= ImageTk.PhotoImage(load)  
            load = Image.open("7.jpg")
            var7= ImageTk.PhotoImage(load)  
            load = Image.open("8.jpg")
            var8= ImageTk.PhotoImage(load)  
            load = Image.open("9.jpg")
            var9= ImageTk.PhotoImage(load)
            load = Image.open("10.jpg")
            var10= ImageTk.PhotoImage(load)
            load = Image.open("11.jpg")
            var11= ImageTk.PhotoImage(load)
            load = Image.open("12.jpg")
            var12= ImageTk.PhotoImage(load)
            load = Image.open("13.jpg")
            var13= ImageTk.PhotoImage(load)
            load = Image.open("14.jpg")
            var14= ImageTk.PhotoImage(load)
            load = Image.open("15.jpg")
            var15= ImageTk.PhotoImage(load)
            load = Image.open("16.jpg")
            var16= ImageTk.PhotoImage(load)
            load = Image.open("17.jpg")
            var17= ImageTk.PhotoImage(load)
            load = Image.open("18.jpg")
            var18= ImageTk.PhotoImage(load)
            load = Image.open("19.jpg")
            var19= ImageTk.PhotoImage(load)
            load = Image.open("20.jpg")
            var20= ImageTk.PhotoImage(load)
            load = Image.open("21.jpg")
            var21= ImageTk.PhotoImage(load)
            load = Image.open("22.jpg")
            var22= ImageTk.PhotoImage(load)
            load = Image.open("23.jpg")
            var23= ImageTk.PhotoImage(load)
            load = Image.open("24.jpg")
            var24= ImageTk.PhotoImage(load)
            load = Image.open("25.jpg")
            var25= ImageTk.PhotoImage(load)
            load = Image.open("26.jpg")
            var26= ImageTk.PhotoImage(load)
            load = Image.open("27.jpg")
            var27= ImageTk.PhotoImage(load)
            load = Image.open("28.jpg")
            var28= ImageTk.PhotoImage(load)
            load = Image.open("29.jpg")
            var29= ImageTk.PhotoImage(load)
            canvas.bind("<Motion>",pick)
            root.mainloop()

# %%
import  socket
ip = '192.168.56.1'
port = 5000
s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
s.bind((ip,port))
s.listen(5)

while True:
    c,addr=s.accept()
    print("Got a connection from %s" % str(addr))
    while True:
        data = c.recv(1024)
        list2.append(data)
s.close()
# Out:
# Got a connection from ('192.168.56.1', 61816)
# Server recv: HI
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-27648204960b> in <module>
#      15             print("Client is lost...")
#      16             break
# ---> 17         msg = input("Please input a message:")
#      18         c.send(data.upper())
#      19         c.send(msg.encode('utf-8'))
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
from tkinter import *
import tkinter as tk
from PIL  import Image, ImageTk
import random

flag=1  #方向标志，2为向左，1为向右
a=1  #记录图片变量的编号，同时也与图片名称对应
x=0  #鼠标位置横坐标
root = Tk()
root.title("走路")
root.geometry("1000x800")
canvas = Canvas(root,width=1000, height=800,bg='white')
canvas.pack()

#获得鼠标位置，判断当前方向
def callback(event):
    global x,flag
    if event.x-x<0:
        flag=2
        a=4
    else:
        flag=1
        a=0
    x = event.x

#移动鼠标，根据方向绘制新图形
def pick(event):
    global a,flag   
    if flag==1:
        a+=1
        if a>=5:
            a=1
    else:			
        a+=1
        if a>=9:
            a=5
    xx=x
    if xx>=520:
        xx=750
        canvas.delete('a')
        canvas.create_image(xx,200,image=var9,tags="a")
        return
    canvas.delete('a')
    exec('canvas.create_image(xx,150,image=var{},tags="a")'.format(a))

#存储初始九张图，1-4为向右，5-8为向左，9为跌倒
#这里可以用之前说过的批量创建或者放到一个列表里，但为了更清晰，才分开写在这里
load = Image.open("1.jpg")
var1= ImageTk.PhotoImage(load)  
load = Image.open("2.jpg")
var2= ImageTk.PhotoImage(load)  
load = Image.open("3.jpg")
var3= ImageTk.PhotoImage(load)  
load = Image.open("4.jpg")
var4= ImageTk.PhotoImage(load)  
load = Image.open("5.jpg")
var5= ImageTk.PhotoImage(load)  
load = Image.open("6.jpg")
var6= ImageTk.PhotoImage(load)  
load = Image.open("7.jpg")
var7= ImageTk.PhotoImage(load)  
load = Image.open("8.jpg")
var8= ImageTk.PhotoImage(load)  
load = Image.open("9.jpg")
var9= ImageTk.PhotoImage(load)  
canvas.create_rectangle(600,220,620,260,fill='black')  #石头
canvas.create_image((100,150), image=var1,tags='a')  #初始小人
canvas.bind("<Motion>",pick)
root.bind("<Motion>",callback)
root.mainloop()
